# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
train_dir = '../data/train'
test_dir = '../data/test'
val_dir = '../data/val'

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(150, 150), batch_size=32, class_mode='binary')

validation_generator = val_datagen.flow_from_directory(
    val_dir, target_size=(150, 150), batch_size=32, class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=(150, 150), batch_size=32, class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples//train_generator.batch_size,
    epochs=15,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples//validation_generator.batch_size)
# Out:
# Epoch 1/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 171s 994ms/step - accuracy: 0.8198 - loss: 0.4309 - val_accuracy: 0.7500 - val_loss: 0.5403
# Epoch 2/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 158s 970ms/step - accuracy: 0.8940 - loss: 0.2552 - val_accuracy: 0.7500 - val_loss: 0.4822
# Epoch 3/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 284s 2s/step - accuracy: 0.9153 - loss: 0.2130 - val_accuracy: 0.6250 - val_loss: 0.6322
# Epoch 4/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.9227 - loss: 0.1946 - val_accuracy: 0.8750 - val_loss: 0.3290
# Epoch 5/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 320s 2s/step - accuracy: 0.9156 - loss: 0.2008 - val_accuracy: 0.6250 - val_loss: 0.5769
# Epoch 6/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 272s 2s/step - accuracy: 0.9266 - loss: 0.1822 - val_accuracy: 0.6875 - val_loss: 0.6301
# Epoch 7/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 265s 2s/step - accuracy: 0.9227 - loss: 0.1921 - val_accuracy: 0.7500 - val_loss: 0.5094
# Epoch 8/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 266s 2s/step - accuracy: 0.9281 - loss: 0.1804 - val_accuracy: 0.8125 - val_loss: 0.4455
# Epoch 9/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.9285 - loss: 0.1787 - val_accuracy: 0.7500 - val_loss: 0.4839
# Epoch 10/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9262 - loss: 0.1811 - val_accuracy: 0.8750 - val_loss: 0.3914
# Epoch 11/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 267s 2s/step - accuracy: 0.9317 - loss: 0.1669 - val_accuracy: 0.7500 - val_loss: 0.4583
# Epoch 12/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 264s 2s/step - accuracy: 0.9335 - loss: 0.1729 - val_accuracy: 0.7500 - val_loss: 0.4953
# Epoch 13/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.9291 - loss: 0.1758 - val_accuracy: 0.8125 - val_loss: 0.4206
# Epoch 14/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.9348 - loss: 0.1675 - val_accuracy: 0.7500 - val_loss: 0.4791
# Epoch 15/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 373s 2s/step - accuracy: 0.9285 - loss: 0.1745 - val_accuracy: 0.8125 - val_loss: 0.4547
