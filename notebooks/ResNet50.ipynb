# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
train_dir = '../data/train'
test_dir = '../data/test'
val_dir = '../data/val'

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(150, 150), batch_size=32, class_mode='binary')

validation_generator = val_datagen.flow_from_directory(
    val_dir, target_size=(150, 150), batch_size=32, class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=(150, 150), batch_size=32, class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples//train_generator.batch_size,
    epochs=15,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples//validation_generator.batch_size)
# Out:
# Epoch 1/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 342s 2s/step - accuracy: 0.7377 - loss: 0.5834 - val_accuracy: 0.5000 - val_loss: 0.8345
# Epoch 2/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 293s 2s/step - accuracy: 0.7429 - loss: 0.5586 - val_accuracy: 0.5000 - val_loss: 0.8021
# Epoch 3/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 320s 2s/step - accuracy: 0.7429 - loss: 0.5445 - val_accuracy: 0.5000 - val_loss: 0.7494
# Epoch 4/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 273s 2s/step - accuracy: 0.7431 - loss: 0.5320 - val_accuracy: 0.5000 - val_loss: 0.8602
# Epoch 5/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 0.7433 - loss: 0.5208 - val_accuracy: 0.5000 - val_loss: 0.7630
# Epoch 6/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 267s 2s/step - accuracy: 0.7464 - loss: 0.5153 - val_accuracy: 0.5000 - val_loss: 0.8315
# Epoch 7/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.7460 - loss: 0.5037 - val_accuracy: 0.5000 - val_loss: 0.8141
# Epoch 8/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 0.7483 - loss: 0.5010 - val_accuracy: 0.5000 - val_loss: 0.8008
# Epoch 9/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 272s 2s/step - accuracy: 0.7519 - loss: 0.4922 - val_accuracy: 0.5000 - val_loss: 0.7597
# Epoch 10/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 267s 2s/step - accuracy: 0.7538 - loss: 0.4872 - val_accuracy: 0.5000 - val_loss: 0.7345
# Epoch 11/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 266s 2s/step - accuracy: 0.7577 - loss: 0.4792 - val_accuracy: 0.5000 - val_loss: 0.7999
# Epoch 12/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 283s 2s/step - accuracy: 0.7556 - loss: 0.4775 - val_accuracy: 0.5000 - val_loss: 0.7717
# Epoch 13/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 350s 2s/step - accuracy: 0.7644 - loss: 0.4715 - val_accuracy: 0.5000 - val_loss: 0.7573
# Epoch 14/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 214s 1s/step - accuracy: 0.7669 - loss: 0.4655 - val_accuracy: 0.5000 - val_loss: 0.8086
# Epoch 15/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.7676 - loss: 0.4653 - val_accuracy: 0.5000 - val_loss: 0.7550
